# %%
#A function is a resualble block of code that performs a task
#Function =code that runs when we call it
def greet():
    print("hello")
greet()
# Out:
# hello

# %%
def add(a,b):
    print(a+b)
add(5,3)
# Out:
# 8

# %%
def show():
    print("python")
show()
# Out:
# python

# %%
def add(a,b):
    return a+b
result=add(3,5)
print(result)
# Out:
# 8

# %%
def add(a,b):
    return a+b
print(2+3)
# Out:
# 5

# %%
def add(a,b):
    return a+b
print(add(2,3))
# Out:
# 5

# %%
#default parametr sometimes we give a default value
def greet(name= "Guest"):
    print("hello" , name)
greet()
# Out:
# hello Guest

# %%
def greet(name="Two"):
    print(name)
greet()
# Out:
# Two

# %%
def add(*nums):
    print(sum(nums))
add(1,2,3)
# Out:
# 6

# %%
def show(*x):
    print(len(x))
show(1,2,3,4)
# Out:
# 4

# %%
def show(**data):
    print(data)
show(name="Alex",age=25)
# Out:
# {'name': 'Alex', 'age': 25}

# %%
data={
    "name":"Alex",
    "age":25
}
print(data)
# Out:
# {'name': 'Alex', 'age': 25}

# %%
def show(**x):
    print(len(x))
show(a=1,b=2)
# Out:
# 2
