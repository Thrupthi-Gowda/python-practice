# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)
# Out:
#  20
#  2
# 10
# 10.0

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)
# Out:
#  30
#  3
# 10
# 10.0

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)
# Out:
#  25
#  5
# 5
# 5.0

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)
# Out:
#  80
#  4
# 20
# 20.0

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)
