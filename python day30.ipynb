# %%
#if else problems
n=int(input())
if n>0:
    print("positive")
elif n<0:
    print("negative")
else:
    print("zero")
# Out:
#  10
# positive

# %%
n=int(input())
if n>0:
    print("positive")
elif n<0:
    print("negative")
else:
    print("zero")
# Out:
#  -15
# negative

# %%
n=int(input())
if n%2!=0:
    print("weird")
elif n>=2 and n<=5:
    print("not weird")
elif n>=6 and n<=20:
    print("weird")
else:
    print("not weird")
# Out:
#  20
# weird

# %%
n=int(input())
if n%2!=0:
    print("weird")
elif n>=2 and n<=5:
    print("not weird")
elif n>=6 and n<=20:
    print("weird")
else:
    print("not weird")
# Out:
#  1
# weird
