# %%
#Basic understing creating a four variable
name="Thrupthi"
age=22
height=6.0
is_student=True
print(name,age,height,is_student)
# Out:
# Thrupthi 22 6.0 True

# %%
x="10"
y=5
print(int(x)*y)
# Out:
# 50

# %%
x="10"
y=5
print(x*y)
# Out:
# 1010101010

# %%
a=7
b=2
print(a/b)
print(a//b)
print(a%b)
# Out:
# 3.5
# 3
# 1

# %%
#convert string into integer
num="25"
print(int(25))
# Out:
# 25

# %%
x=5
y=2.0
z=x+y
print(type(z))
# Out:
# <class 'float'>

# %%
#converstion of int into string
x=10
y=str(x)
print(type(y))
# Out:
# <class 'str'>

# %%
#conversion of strig into integer
x="10"
y=int(x)
print(type(y))
# Out:
# <class 'int'>

# %%
print(bool(""))
print(bool(0))
print(bool(100))
# Out:
# False
# False
# True

# %%
#we start only letters or the underscore
name="Rahul"
print(name)
# Out:
# Rahul

# %%
# predict the output
print(2+3*2**2)
# Out:
# 14

# %%
print(2**2)
# Out:
# 4

# %%
print(3*4)
# Out:
# 12

# %%
print(2+12)
# Out:
# 14

# %%
#take two numbers add them multiply them divide them show remainder
a=5
b=5
print(a+b)
print(a*b)
print(a/b)
print(a%b)
# Out:
# 10
# 25
# 1.0
# 0

# %%
#write a python program to check if a number is EVEN or ODD
num=int(input("enter the number "))
if num%2==0 :
    print(" even")
else:
    print( "odd")
# Out:
# enter the number  22
#  even

# %%
#write a python program to check if a number is EVEN or ODD
num=int(input("enter the number "))
if num%2==0 :
    print(" even")
else:
    print( "odd")
# Out:
# enter the number  25
# odd

# %%
if num%1==0:
    print("even")
# Out:
# even

# %%
#Two types of type conversion are there implicit type conversion 1.implicit 
a=5
b=2.5
c=a+b
print(c)
print(type(c))
# Out:
# 7.5
# <class 'float'>

# %%
#2.explicit type conversion
x="100"
y=int(x)
print(y)
print(type(y))
# Out:
# 100
# <class 'int'>

# %%
#string + string
print("10"+"5")
# Out:
# 105

# %%
#string + integer is not possible
chandan=5
print("15"+int(chandan))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 3
#       1 #string + integer is not possible
#       2 chandan=5
# ----> 3 print("15"+int(chandan))
#
# TypeError: can only concatenate str (not "int") to str

# %%
#float to int
a=5
b=3.5
print(type(a+b))#float to int
# Out:
# <class 'float'>

# %%
#float to int
a=5
b=3.5
print(int(a+b))
print(type(a+b))#float to int
# Out:
# 8
# <class 'float'>

# %%
#int into string
age=21
print("my age is"+str(age))
# Out:
# my age is21

# %%
print(bool(0))
print(bool(""))
print(bool(1))
print(bool("hello"))
