# %%
#A module is simply a python file that contains functions or variables
math_utils.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #A module is simply a python file that contains functions or variables
# ----> 2 math_utils.py
#
# NameError: name 'math_utils' is not defined

# %%
def add(a,b):
    return a+b

# %%
import math_utils
print(math_utils.add(5,3))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import math_utils
#       2 print(math_utils.add(5,3))
#
# ModuleNotFoundError: No module named 'math_utils'

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
import random
print(random.randint(1,10))
# Out:
# 10

# %%
import math
from math import sqrt
print(sqrt(25))
# Out:
# 5.0

# %%
def greet():
    print("hello")
if __name__=="__main__":
    greet()
# Out:
# hello

# %%
__name__=="__main__"
# Out:
# True

# %%
import math
print(math.sqrt(36))
# Out:
# 6.0

# %%
try:
    x=int("5")
    print(x)
except valueError:
    print("invalid")
finally:
    print("end")
# Out:
# 5
# end

# %%
x=5
y=2
print(x** y)
