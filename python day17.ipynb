# %%
try:
    x=int("hello")
except ValueError:
    print("Wrong value")
# Out:
# Wrong value

# %%
try:
    print(10/2)
except:
    print("Error")
finally:
    print("Done")
# Out:
# 5.0
# Done

# %%
try:
    print(10/0)
except:
    print("Error")
finally:
    print("Finished")
# Out:
# Error
# Finished

# %%
try:
    print(10/0)
except:
    print("error")
finally:
    print("finished")
# Out:
# error
# finished

# %%
try:
    print(5)
except:
    print("error")
finally:
    print("Done")
# Out:
# 5
# Done

# %%
try:
    print(5)
except:
    print("error")
finally:
    print("Done")
# Out:
# 5
# Done

# %%
#File handling 
#Read files
#Write files
#Save data
file=open("data.txt","w")
file.write("Hello")
file.close()
