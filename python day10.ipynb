# %%
a=10
b=a
a=20
print(b)
# Out:
# 10

# %%
x=5
y=5
print(x is y)
# Out:
# True

# %%
name="Python"
print(name[0])
# Out:
# P

# %%
a=3
b=4
print(a+b)
# Out:
# 7

# %%
x=10
def change():
    x=20
change()
print(x)
# Out:
# 10

# %%
y=-5
print(type(y))
# Out:
# <class 'int'>

# %%
y=-5
print(abs(y))
# Out:
# 5

# %%
#IF STATEMET
age=10
if age>=10:
    print("you can vote")
# Out:
# you can vote

# %%
#if else
age=16
if age>=10:
    print("you can vote")
else:
    print("you cannot vote")
# Out:
# you can vote

# %%
marks=75
if marks>=90 :
    print("A Grade")
elif marks>=50 :
    PRINT("pass")
else:
    print("Fail")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       3     print("A Grade")
#       4 elif marks>=50 :
# ----> 5     PRINT("pass")
#       6 else:
#       7     print("Fail")
#
# NameError: name 'PRINT' is not defined
