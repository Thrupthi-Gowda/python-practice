# %%
'''file handling 
work with files on your computer
you learn:
.read files
.write files
.append data
.file=open("data.txt","w")
.file.write("hello")
.file.close()
.a module is a python file containg functions'''
# Out:
# 'file handling \nwork with files on your computer\nyou learn:\n.read files\n.write files\n.append data\n.file=open("data.txt","w")\n.file.write("hello")\n.file.close()\n.a module is a python file containg functions'

# %%
#modules
#A module is a python file containg functions
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
file=open("data.txt","w")
file.write("Hello Python")
file.close()

# %%
with open("data.txt","w") as file:
    file.write("hello")

# %%
with open("data.txt","w")as f:
    f.write("A")
with open("data.txt","a")as f:
    f.write("B")
with open("data.txt","r")as f:
    print(f.read())
# Out:
# AB

# %%
with open("test.txt","w")as f:
    f.write("hello")
with open("test.txt","r")as f:
    print(len(f.read()))
# Out:
# 5

# %%
import math
print(math.sqrt(25))
# Out:
# 5.0

# %%
def add(a,b):
    return a+b
