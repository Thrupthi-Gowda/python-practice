# %%
#variable
a=10
b=20
print(a+b)
# Out:
# 30

# %%
#Type conversion
a=3
b=2
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a^b)
print(a//b)
# Out:
# 5
# 1
# 6
# 1.5
# 1
# 1
# 1

# %%
#data types
a=10
print(type(a))
a="chandu"
print(type(a))
a=True
print(type(a))
a=2.5
print(type(a))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'float'>

# %%
#dynamically typed language is python 
x=10
name="rahul"
print(x)
print(name)
# Out:
# 10
# rahul

# %%
#type error at runtime
a=5
b="10"
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 a=5
#       3 b="10"
# ----> 4 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#type errror solve 
a=str(5)
b="10"
print(a+b)
# Out:
# 510

# %%
a=5
b=int("10")
print(a+b)
# Out:
# 15

# %%
#string method
message="Hello,World!"
print(message.strip())
print(message.upper())
print(message.lower())
print(message.split())
# Out:
# Hello,World!
# HELLO,WORLD!
# hello,world!
# ['Hello,World!']

# %%
#accessing string character
test="python"
print(test[0])
print(test[5])
# Out:
# p
# n

# %%
#it consider the space as the index
test="I am a data scientist worker."
print(test[-3])
print(test[4])
print(test[3])
print(test[-1])
# Out:
# e
#
# m
# .

# %%
#repitation
chandu=" person "
print(chandu*3)
# Out:
#  person  person  person

# %%
#slicing
chandu="google developer"
print(chandu[0:6])
print(chandu[7:17])
# Out:
# google
# developer

# %%
#comment line is used for the what are the topic is there it is not print what you writtern

# %%
"""
this is a multiline comment
is used for the same
purpose as coment line
"""
print("Hello World")
# Out:
# Hello World

# %%
#next line tab space black slash
print("hello\nWords")
print("hello\tWords")
print("hello\\words")
# Out:
# hello
# Words
# hello	Words
# hello\words

# %%
#write a program using input user and formt specifier "My name is chandan. My age is 22"
name=input("enter the name:")
age=int(input("enter the age:"))
print(f"My name is {name}.My age is {age}")
# Out:
# enter the name: chandan
# enter the age: 22
# My name is chandan.My age is 22
