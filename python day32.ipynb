# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a+b)
    print(a-b)
    print(a*b)
# Out:
#  10
#  20
# 30
# -10
# 200

# %%
n=int(input())
if (n%2 !=0):
    print("Weird")
else:
    if (n>=2 and n<=5):
        print("Not Weird")
    elif(n>=6 and n<=20):
        print("Weird")
    else:
        print("not werid")
# Out:
#  4
# Not Weird
