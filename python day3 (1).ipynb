# %%
#command operator
a=10
b=20
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
#logical operator not
x=5
y=10
z=15
#and operator
print(x>0 and y>5)
# Out:
# True

# %%
#logicaloperator
x=10
y=5
print(x>15 or y<1)
# Out:
# False

# %%
#membership operator
my_list=[1,2,3,4,5]
my_string="python"
print(3 in my_list)
print(6 in my_list)
print("y" in my_string)
print("z" in my_string)
# Out:
# True
# False
# True
# False

# %%
a=5
b=3
print(a&b)
# Out:
# 1

# %%
a=5
b=4
print(a&b)
# Out:
# 4

# %%
#list a collection of item that are ordered
fruits=["apple","banana","cherry"]
number=[1,2,3,4,5]
mixed=["apples",1,True]
print(mixed[2])
print(number[4])
print(fruits[2])
print(fruits[-2])
# Out:
# True
# 5
# cherry
# banana

# %%
# modified list
fruits=["apples","banana","cherry"]
fruits.append("greph")
print(fruits)
# Out:
# ['apples', 'banana', 'cherry', 'greph']

# %%
orange=["yellow","blue","red"]
orange.append("nevy blue")
print(orange)
# Out:
# ['yellow', 'blue', 'red', 'nevy blue']

# %%
numbers=[0,1,2,3,4,5,6]
print(numbers[1:4])
print(numbers[2:5])
# Out:
# [1, 2, 3]
# [2, 3, 4]
