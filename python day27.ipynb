# %%
print("hello world")
# Out:
# hello world

# %%
a,b=map(int,input().split())
print(a+b)
# Out:
#  5 6
# 11

# %%
n=int(input())
if n%2==0:
    print("even")
else:
    print("odd")
# Out:
#  20
# even

# %%
a,b,c=map(int,input().split())
largest=max(a,b,c)
print(largest)
# Out:
#  12 10 15
# 15

# %%
n=int(input())
for i in range(1,11):
    print(n,"x",i,"=",n
