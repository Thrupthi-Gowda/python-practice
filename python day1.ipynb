# %%
#writing first code in python
print("hello world")
# Out:
# hello world

# %%
#input user
work=input("my name is chandan im working at ")
degree=input("I am currently pursuing ")
branch=input("bacholer in ")
college=input("at")
# Out:
# my name is chandan im working at  google
# I am currently pursuing  engineering
# bacholer in  computer science
# at aAJIET mangalore kottara chowki

# %%
#storing a value
age=input("Age:")
print(age)
# Out:
# Age: 22
# 22

# %%
#creating a sentence joining the letters
boyname=input("enter the boyname\n")
mothername=input ("enter the mothername\n")
print(boyname +"loves his mother"+mothername)
# Out:
# enter the boyname
#  chandan
# enter the mothername
#  satyavathi
# chandanloves his mothersatyavathi

# %%
#creating a sentence joining the letters
boyname=input("enter the boyname\n")
mothername=input ("enter the mothername\n")
print(boyname ,"loves his mother",mothername)
# Out:
# enter the boyname
#  chandan
# enter the mothername
#  satyavathi
# chandan loves his mother satyavathi

# %%
#finding the age difference between the  girl and the boy
boy_name=input("enter the boy name")
boy_age =int(input("enter the age of the boy"))
girl_name=input("enter the girl name")
girl_age=int(input("enter the age of the girl"))
difference=abs(boy_age-girl_age)
print(boy_name,"fav sis",girl_name,"age difference is",difference)
# Out:
# enter the boy name chandan
# enter the age of the boy 22
# enter the girl name thrupthi
# enter the age of the girl 19
# chandan fav sis thrupthi age difference is 3

# %%
#finding the age difference between the  girl and the boy using the format specifier
boy_name=input("enter the boy name")
boy_age =int(input("enter the age of the boy"))
girl_name=input("enter the girl name")
girl_age=int(input("enter the age of the girl"))
difference=abs(boy_age-girl_age)
print(f"{boy_name}fav sis{girl_name}age difference is{difference})
# Out:
#   Cell In[20], line 7
#     print(f"boy:{boy_name}fav sisgirl:{girl_name}age difference is{difference})
#           ^
# SyntaxError: unterminated f-string literal (detected at line 7)
