# %%
n=int(input())
if n%2==1:
    print("Weird")
elif 2<=n<=5:
    print("Not Weird")
elif 6<=n<=20:
    print("Weird")
else:
    print("Not Weird")
# Out:
#  3
# Weird

# %%
n=int(input())
if n%2==1:
    print("Weird")
elif 2<=n<=5:
    print("Not Weird")
elif 6<=n<=20:
    print("Weird")
else:
    print("Not Weird")
# Out:
#  24
# Not Weird

# %%
n=int(input())
if n%2==1:
    print("Weird")
elif 2<=n<=5:
    print("Not Weird")
elif 6<=n<=20:
    print("Weird")
else:
    print("Not Weird")
# Out:
#  25
# Weird

# %%
n=int(input())
if n%2==1:
    print("Weird")
elif 2<=n<=5:
    print("Not Weird")
elif 6<=n<=20:
    print("Weird")
else:
    print("Not Weird")
# Out:
#  4
# Not Weird

# %%
n=int(input())
if n%2==1:
    print("Weird")
elif 2<=n<=5:
    print("Not Weird")
elif 6<=n<=20:
    print("Weird")
else:
    print("Not Weird")
# Out:
#  8
# Weird

# %%
def is_leap(year):
    if year %400==0:
        return True
    elif year %100==0:
        return False
    elif year %4==0:
        return True
    else:
        return False
year = int(input())
print(is_leap(year))

# %%
n=int(input())
if n%2!=0:
    print("Weird")
elif 2<=n<=5:
    print("Not Weird")
elif 6<=n<=20:
    print("Weird")
else:
    print("Not Weird")
# Out:
#  20
# Weird

# %%
print("Hello,World")
# Out:
# Hello,World

# %%
a=int(input())
b=int(input())
print(a+b)
print(a-b)
print(a*b)
# Out:
#  5
#  2
# 7
# 3
# 10

# %%
a=int(input())
b=int(input())
print(a//b)
print(a/b)
# Out:
#  5
#  10
# 0
# 0.5

# %%
n=int(input())
for i in range(n):
    print(i**2)
# Out:
#  4
# 0
# 1
# 4
# 9

# %%
n=int(input())
for i in range(n):
    print(i**2)
# Out:
#  3
# 0
# 1
# 4

# %%
def is_leap(year):
    if year % 400 ==0:
        return True
    elif year % 100 ==0:
        return False
    elif year % 4 ==0:
        return True
    else:
        return False
year=int(input())
print(is_leap(year))
# Out:
#  20
# True

# %%
if __name__=="__main__":
    n=int(input())
    for i in range(1,n+1):
        print(i,end="")
# Out:
#  20
# 1234567891011121314151617181920
