# %%
#A list is a collection of multiple values stored in one variable
num=[10,20,30,40]
print(num)
# Out:
# [10, 20, 30, 40]

# %%
num=[10,20,30,40]
print(num[0])
# Out:
# 10

# %%
num=[10,20,30,40]
print(num[3])
# Out:
# 40

# %%
num=[10,20,30,40]
print(num[-1])
# Out:
# 40

# %%
#list can store different data types
data=[10,"hello",3.5,True]
print(data)
# Out:
# [10, 'hello', 3.5, True]

# %%
#list can store different data types
data=[10,"hello",3.5,True]
print(data[2])
# Out:
# 3.5

# %%
a=[5,10,15]
print(a[1])
# Out:
# 10

# %%
number=[10,20]
number.append(30)
print(number)
# Out:
# [10, 20, 30]

# %%
numbers=[10,20]
numbers.insert(1,15)
print(numbers)
# Out:
# [10, 15, 20]

# %%
number=[10,20,30]
number.remove(30)
print(number)
# Out:
# [10, 20]

# %%
a=[1,2]
a.append(3)
print(a)
# Out:
# [1, 2, 3]

# %%
num=[10,20,30,40,50]
print(num[1:4])
# Out:
# [20, 30, 40]

# %%
a=[10,20,30]
print(len(a))
# Out:
# 3

# %%
a=[3,1,2]
a.sort()
print(a)
# Out:
# [1, 2, 3]

# %%
a=[1,2,3]
a.reverse()
print(a)
# Out:
# [3, 2, 1]

# %%
a=[1,2,3]
a.sort()
print(a[1])
# Out:
# 2

# %%
#A tuple is like a list but cannot be changed
t=(10,20,30)
print(t)
# Out:
# (10, 20, 30)

# %%
t=(10,20,30,40,50)
print(t[3])
# Out:
# 40

# %%
t=(5,10,15)
print(t[2])
# Out:
# 15

# %%
t=(5,10,15)
print(t[1])
# Out:
# 10

# %%
t=(1,2,2,4)
print(t.count(2))
# Out:
# 2

# %%
t=(10,20,30)
print(t.index(20))
# Out:
# 1

# %%
#set is a collection of unique values
#Set = no duplicate values 
s={1,2,3,4}
print(s)
# Out:
# {1, 2, 3, 4}

# %%
#Duplicate values automatically removed
s={1,2,2,3,3,4}
print(s)
# Out:
# {1, 2, 3, 4}

# %%
s={1,2}
s.add(3)
print(s)
# Out:
# {1, 2, 3}

# %%
#if add the value to the set then use the add function not the append function 
s={"a","b","c"}
s.add("d")
print(s)
# Out:
# {'b', 'd', 'c', 'a'}

# %%
s={1,2,2,3}
print(len(s))
# Out:
# 3

# %%
#remove()
s={1,2,3}
s.remove(2)
print(s)
# Out:
# {1, 3}

# %%
#set union 
a={1,2}
b={2,3}
print(a|b)
# Out:
# {1, 2, 3}

# %%
#dectionary stores data as key:value pairs
name:"Alex"
age:25
city:"Mysore"

# %%
#Exmple code
student={
    "name":"chandu",
    "age":20,
    "marks":85
}
print(student)
# Out:
# {'name': 'chandu', 'age': 20, 'marks': 85}

# %%
#Exmple code
student={"name":"chandu","age":20,"marks":85}
print(student)
# Out:
# {'name': 'chandu', 'age': 20, 'marks': 85}

# %%
d={"a":10,"b":20}
print(d["a"])
# Out:
# 10

# %%
student={"name":"chandu","age":20}
student["age"]=21
print(student)
# Out:
# {'name': 'chandu', 'age': 21}

# %%
d={"x":5}
d["y"]=10
print(len(d))
# Out:
# 2
