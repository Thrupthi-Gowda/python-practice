# %%
n = int(input())

if n % 2 == 1:
    print("Weird")
else:
    print("Not Weird")
# Out:
#  10
# Not Weird

# %%
n = int(input())

if n % 2 == 1:
    print("Weird")
else:
    print("Not Weird")
# Out:
#  2
# Not Weird

# %%
n = int(input())

if n % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
#  2
# Even

# %%
n = int(input())

if n >= 0:
    print("Positive")
else:
    print("Negative")
# Out:
#  3
# Positive

# %%
marks = int(input())

if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
#  40
# Pass

# %%
a = int(input())
b = int(input())

if a > b:
    print(a)
else:
    print(b)
