# %%
def hello():
    print("hi")
h=hello()
# Out:
# hi

# %%
class A:
    x=10

# %%
#This is very imporatant because it handles errors in programs.
print(10/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 #This is very imporatant because it handles errors in programs.
# ----> 2 print(10/0)
#
# ZeroDivisionError: division by zero

# %%
try:
    print(10/0)
except:
    print("Error happened")
# Out:
# Error happened

# %%
try:
    x=int("abc")
except:
    print("invalid number")
# Out:
# invalid number

# %%
try:
    print(5/0)
except:
    print("error")
# Out:
# error

# %%
try:
    print(10/0)
except zeroDivisonError:
    print("cannot divided by zero")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 try:
# ----> 2     print(10/0)
#       3 except zeroDivisonError:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 try:
#       2     print(10/0)
# ----> 3 except zeroDivisonError:
#       4     print("cannot divided by zero")
#
# NameError: name 'zeroDivisonError' is not defined

# %%
try:
    x=int("hello")
except ValueError:
    print("wrong value")
# Out:
# wrong value
